# %%
import re
import time
import glob
import requests
import unicodedata
import numpy as np
import pandas as pd
from time import strftime
from bs4 import BeautifulSoup
from selenium import webdriver

# %% [markdown]
# # Definição do Problema:
# A area de negócio da wine.com gostaria de saber, antes de incluir no mix de produtos, qual o provável rating daquele vinho!
#
# #### Estratégia:
# Capturar caracteristicas do produto alvo (Vinho) que sejam facilmente replicaveis para os produtos candidatos. Tais como:
#
# - País
# - Premiações
# - descrição (ex. Gustativo)
# - Quantidade de Mls
# - Entre outras
#
# A variável TARGET são os Rating que cada vinho tenha recebido, caso o vinho não tenha avaliação, será considerado Rating 0.
#
# #### Outros Objetivos:
#
# Adicionalmente gostariamos também de responder algumas perguntas com nos dados capturados, tais como:
#
# - Qual os países com vinhos de maiores ratings? Será os franceses melhores?
# - E com relação a premiações? Qual a nacionalidade de vinho com maior quantidade de premiações?
# - Existe alguma correlação entre quantidade de premiações e ratings?

# %% [markdown]
# # 1. Definir funções auxiliares

# %%
#Funções Auxiliares

def get_url(url, driver):

    """
    Formula para acessar a url.
    """
    urlpage = url
    driver.get(urlpage)
    time.sleep(30)

def quit_driver(driver):
    """
    Formula para Fechar o driver
    """
    driver.quit()

def removerAcentosECaracteresEspeciais(palavra):

    """
    Função para remoção de acentos e caracteres especiais.
    Creditos para ...
    """

    # Unicode normalize transforma um caracter em seu equivalente em latin.
    nfkd = unicodedata.normalize('NFKD', palavra)
    palavraSemAcento = u"".join([c for c in nfkd if not unicodedata.combining(c)])

    # Usa expressão regular para retornar a palavra apenas com números, letras e espaço
    return re.sub('[^a-zA-Z0-9 \\\]', '', palavraSemAcento)

def merge_csv_folder(prefix, path, memory='no'):

    """
    Formula para concatenar arquivos .csv's dentro de uma determinada pasta.
    """
    if path == '':
        path = input("Por favor digite o endereços dos arquivos?\n")
    path = path.replace('\\','/')
    if path[:-1] != '/':
        path = path + '/'

    file_list = glob.glob(path + '*.csv')

    combined = pd.concat([pd.read_csv(f) for f in file_list], axis=1)
    if memory == 'no':
        combined.to_csv(path + f'combined_{prefix}_{strftime("%Y%m%d-%H%M%S")}.csv', index=False)
    else:
        return combined
    print('Feito')

# %% [markdown]
# # 2. Capturar variáveis
#
# - Sku
# - Produto
# - País
# - Mls
# - Awards
# - Titulo Descrição
# - Descrição

# %%
#Sku
driver = webdriver.Firefox(executable_path='C:/Windows/System32/drivers/DriverData/geckodriver.exe')
dados_sku=[]

for i in range(1,84):
    PAGE = f'https://www.wine.com.br/vinhos/cVINHOS-p{i}.html'
    print(f'Raspando pagina {i}')

    driver.get(PAGE)
    resultado = driver.find_elements_by_xpath(".//*[@class='ProductDisplay-content']//*[@class='js-productClick']")
    for result in resultado:
        sku = result.get_attribute('data-product-sku')
        dados_sku.append({'Sku':sku})
quit_driver(driver)
df = pd.DataFrame(dados_sku, columns = ['Sku'])
df.to_csv('csv/sku.csv')
# Out:
# Raspando pagina 1
# Raspando pagina 2
# Raspando pagina 3
# Raspando pagina 4
# Raspando pagina 5
# Raspando pagina 6
# Raspando pagina 7
# Raspando pagina 8
# Raspando pagina 9
# Raspando pagina 10
# Raspando pagina 11
# Raspando pagina 12
# Raspando pagina 13
# Raspando pagina 14
# Raspando pagina 15
# Raspando pagina 16
# Raspando pagina 17
# Raspando pagina 18
# Raspando pagina 19
# Raspando pagina 20
# Raspando pagina 21
# Raspando pagina 22
# Raspando pagina 23
# Raspando pagina 24
# Raspando pagina 25
# Raspando pagina 26
# Raspando pagina 27
# Raspando pagina 28
# Raspando pagina 29
# Raspando pagina 30
# Raspando pagina 31
# Raspando pagina 32
# Raspando pagina 33
# Raspando pagina 34
# Raspando pagina 35
# Raspando pagina 36
# Raspando pagina 37
# Raspando pagina 38
# Raspando pagina 39
# Raspando pagina 40
# Raspando pagina 41
# Raspando pagina 42
# Raspando pagina 43
# Raspando pagina 44
# Raspando pagina 45
# Raspando pagina 46
# Raspando pagina 47
# Raspando pagina 48
# Raspando pagina 49
# Raspando pagina 50
# Raspando pagina 51
# Raspando pagina 52
# Raspando pagina 53
# Raspando pagina 54
# Raspando pagina 55
# Raspando pagina 56
# Raspando pagina 57
# Raspando pagina 58
# Raspando pagina 59
# Raspando pagina 60
# Raspando pagina 61
# Raspando pagina 62
# Raspando pagina 63
# Raspando pagina 64
# Raspando pagina 65
# Raspando pagina 66
# Raspando pagina 67
# Raspando pagina 68
# Raspando pagina 69
# Raspando pagina 70
# Raspando pagina 71
# Raspando pagina 72
# Raspando pagina 73
# Raspando pagina 74
# Raspando pagina 75
# Raspando pagina 76
# Raspando pagina 77
# Raspando pagina 78
# Raspando pagina 79
# Raspando pagina 80
# Raspando pagina 81
# Raspando pagina 82
# Raspando pagina 83

# %%
# Variavel Produto
driver = webdriver.Firefox(executable_path='C:/Windows/System32/drivers/DriverData/geckodriver.exe')
dados_produto=[]    
    

for i in range(1,84):
    PAGE = f'https://www.wine.com.br/vinhos/cVINHOS-p{i}.html'
    print(f'Raspando pagina {i}')

    driver.get(PAGE)
    resultado = driver.find_elements_by_xpath(".//*[@class='ProductDisplay-content']//*[@class='js-productClick']")
    for result in resultado:
        title = result.get_attribute('title')
        dados_produto.append({'Produto':title})

quit_driver(driver)
df = pd.DataFrame(dados_produto, columns =['Produto'])
df = df.apply(lambda x : removerAcentosECaracteresEspeciais(x['Produto']), axis = 1)
df.to_csv('csv/produto.csv')
# Out:
# Raspando pagina 1
# Raspando pagina 2
# Raspando pagina 3
# Raspando pagina 4
# Raspando pagina 5
# Raspando pagina 6
# Raspando pagina 7
# Raspando pagina 8
# Raspando pagina 9
# Raspando pagina 10
# Raspando pagina 11
# Raspando pagina 12
# Raspando pagina 13
# Raspando pagina 14
# Raspando pagina 15
# Raspando pagina 16
# Raspando pagina 17
# Raspando pagina 18
# Raspando pagina 19
# Raspando pagina 20
# Raspando pagina 21
# Raspando pagina 22
# Raspando pagina 23
# Raspando pagina 24
# Raspando pagina 25
# Raspando pagina 26
# Raspando pagina 27
# Raspando pagina 28
# Raspando pagina 29
# Raspando pagina 30
# Raspando pagina 31
# Raspando pagina 32
# Raspando pagina 33
# Raspando pagina 34
# Raspando pagina 35
# Raspando pagina 36
# Raspando pagina 37
# Raspando pagina 38
# Raspando pagina 39
# Raspando pagina 40
# Raspando pagina 41
# Raspando pagina 42
# Raspando pagina 43
# Raspando pagina 44
# Raspando pagina 45
# Raspando pagina 46
# Raspando pagina 47
# Raspando pagina 48
# Raspando pagina 49
# Raspando pagina 50
# Raspando pagina 51
# Raspando pagina 52
# Raspando pagina 53
# Raspando pagina 54
# Raspando pagina 55
# Raspando pagina 56
# Raspando pagina 57
# Raspando pagina 58
# Raspando pagina 59
# Raspando pagina 60
# Raspando pagina 61
# Raspando pagina 62
# Raspando pagina 63
# Raspando pagina 64
# Raspando pagina 65
# Raspando pagina 66
# Raspando pagina 67
# Raspando pagina 68
# Raspando pagina 69
# Raspando pagina 70
# Raspando pagina 71
# Raspando pagina 72
# Raspando pagina 73
# Raspando pagina 74
# Raspando pagina 75
# Raspando pagina 76
# Raspando pagina 77
# Raspando pagina 78
# Raspando pagina 79
# Raspando pagina 80
# Raspando pagina 81
# Raspando pagina 82
# Raspando pagina 83

# %%
#País
driver = webdriver.Firefox(executable_path='C:/Windows/System32/drivers/DriverData/geckodriver.exe')
dados_country=[]    

for i in range(1,84):
    PAGE = f'https://www.wine.com.br/vinhos/cVINHOS-p{i}.html'
    print(f'Raspando pagina {i}')

    driver.get(PAGE)  
    resultado = driver.find_elements_by_xpath("//*[@class='Country']")
 
    for result in resultado:
        country = result.text
        dados_country.append({'Country':country})

quit_driver(driver)
df = pd.DataFrame(dados_country, columns=['Country'])
df = df.apply(lambda x : removerAcentosECaracteresEspeciais(x['Country']), axis = 1)
df.to_csv('csv/country.csv')
# Out:
# Raspando pagina 1
# Raspando pagina 2
# Raspando pagina 3
# Raspando pagina 4
# Raspando pagina 5
# Raspando pagina 6
# Raspando pagina 7
# Raspando pagina 8
# Raspando pagina 9
# Raspando pagina 10
# Raspando pagina 11
# Raspando pagina 12
# Raspando pagina 13
# Raspando pagina 14
# Raspando pagina 15
# Raspando pagina 16
# Raspando pagina 17
# Raspando pagina 18
# Raspando pagina 19
# Raspando pagina 20
# Raspando pagina 21
# Raspando pagina 22
# Raspando pagina 23
# Raspando pagina 24
# Raspando pagina 25
# Raspando pagina 26
# Raspando pagina 27
# Raspando pagina 28
# Raspando pagina 29
# Raspando pagina 30
# Raspando pagina 31
# Raspando pagina 32
# Raspando pagina 33
# Raspando pagina 34
# Raspando pagina 35
# Raspando pagina 36
# Raspando pagina 37
# Raspando pagina 38
# Raspando pagina 39
# Raspando pagina 40
# Raspando pagina 41
# Raspando pagina 42
# Raspando pagina 43
# Raspando pagina 44
# Raspando pagina 45
# Raspando pagina 46
# Raspando pagina 47
# Raspando pagina 48
# Raspando pagina 49
# Raspando pagina 50
# Raspando pagina 51
# Raspando pagina 52
# Raspando pagina 53
# Raspando pagina 54
# Raspando pagina 55
# Raspando pagina 56
# Raspando pagina 57
# Raspando pagina 58
# Raspando pagina 59
# Raspando pagina 60
# Raspando pagina 61
# Raspando pagina 62
# Raspando pagina 63
# Raspando pagina 64
# Raspando pagina 65
# Raspando pagina 66
# Raspando pagina 67
# Raspando pagina 68
# Raspando pagina 69
# Raspando pagina 70
# Raspando pagina 71
# Raspando pagina 72
# Raspando pagina 73
# Raspando pagina 74
# Raspando pagina 75
# Raspando pagina 76
# Raspando pagina 77
# Raspando pagina 78
# Raspando pagina 79
# Raspando pagina 80
# Raspando pagina 81
# Raspando pagina 82
# Raspando pagina 83

# %%
#MLs
driver = webdriver.Firefox(executable_path='C:/Windows/System32/drivers/DriverData/geckodriver.exe')
dados_ml=[]      
   

for i in range(1,84):
    PAGE = f'https://www.wine.com.br/vinhos/cVINHOS-p{i}.html'
    print(f'Raspando pagina {i}')

    driver.get(PAGE)  
    resultado = driver.find_elements_by_xpath("//*[@class='col-xs-6 ProductDisplay-tag']")
    for result in resultado:
        ml = result.text.strip('ML')
        dados_ml.append({'Mls':ml})

quit_driver(driver)
df = pd.DataFrame(dados_ml, columns = ['Mls'])
df.to_csv('csv/mls.csv' )
# Out:
# Raspando pagina 1
# Raspando pagina 2
# Raspando pagina 3
# Raspando pagina 4
# Raspando pagina 5
# Raspando pagina 6
# Raspando pagina 7
# Raspando pagina 8
# Raspando pagina 9
# Raspando pagina 10
# Raspando pagina 11
# Raspando pagina 12
# Raspando pagina 13
# Raspando pagina 14
# Raspando pagina 15
# Raspando pagina 16
# Raspando pagina 17
# Raspando pagina 18
# Raspando pagina 19
# Raspando pagina 20
# Raspando pagina 21
# Raspando pagina 22
# Raspando pagina 23
# Raspando pagina 24
# Raspando pagina 25
# Raspando pagina 26
# Raspando pagina 27
# Raspando pagina 28
# Raspando pagina 29
# Raspando pagina 30
# Raspando pagina 31
# Raspando pagina 32
# Raspando pagina 33
# Raspando pagina 34
# Raspando pagina 35
# Raspando pagina 36
# Raspando pagina 37
# Raspando pagina 38
# Raspando pagina 39
# Raspando pagina 40
# Raspando pagina 41
# Raspando pagina 42
# Raspando pagina 43
# Raspando pagina 44
# Raspando pagina 45
# Raspando pagina 46
# Raspando pagina 47
# Raspando pagina 48
# Raspando pagina 49
# Raspando pagina 50
# Raspando pagina 51
# Raspando pagina 52
# Raspando pagina 53
# Raspando pagina 54
# Raspando pagina 55
# Raspando pagina 56
# Raspando pagina 57
# Raspando pagina 58
# Raspando pagina 59
# Raspando pagina 60
# Raspando pagina 61
# Raspando pagina 62
# Raspando pagina 63
# Raspando pagina 64
# Raspando pagina 65
# Raspando pagina 66
# Raspando pagina 67
# Raspando pagina 68
# Raspando pagina 69
# Raspando pagina 70
# Raspando pagina 71
# Raspando pagina 72
# Raspando pagina 73
# Raspando pagina 74
# Raspando pagina 75
# Raspando pagina 76
# Raspando pagina 77
# Raspando pagina 78
# Raspando pagina 79
# Raspando pagina 80
# Raspando pagina 81
# Raspando pagina 82
# Raspando pagina 83

# %%
#Awards
driver = webdriver.Firefox(executable_path='C:/Windows/System32/drivers/DriverData/geckodriver.exe')
dados_awards=[]      
   

for i in range(1,84):
    PAGE = f'https://www.wine.com.br/vinhos/cVINHOS-p{i}.html'
    print(f'Raspando pagina {i}')

    driver.get(PAGE)  
    resultado = driver.find_elements_by_xpath("//*[@class='ProductDisplay-new-awards col-xs-6']")
    for result in resultado:
        awards = result.text
        dados_awards.append({'Awards':awards})

quit_driver(driver)
df = pd.DataFrame(dados_awards, columns = ['Awards'])
df.to_csv('csv/awards.csv')
# Out:
# Raspando pagina 1
# Raspando pagina 2
# Raspando pagina 3
# Raspando pagina 4
# Raspando pagina 5
# Raspando pagina 6
# Raspando pagina 7
# Raspando pagina 8
# Raspando pagina 9
# Raspando pagina 10
# Raspando pagina 11
# Raspando pagina 12
# Raspando pagina 13
# Raspando pagina 14
# Raspando pagina 15
# Raspando pagina 16
# Raspando pagina 17
# Raspando pagina 18
# Raspando pagina 19
# Raspando pagina 20
# Raspando pagina 21
# Raspando pagina 22
# Raspando pagina 23
# Raspando pagina 24
# Raspando pagina 25
# Raspando pagina 26
# Raspando pagina 27
# Raspando pagina 28
# Raspando pagina 29
# Raspando pagina 30
# Raspando pagina 31
# Raspando pagina 32
# Raspando pagina 33
# Raspando pagina 34
# Raspando pagina 35
# Raspando pagina 36
# Raspando pagina 37
# Raspando pagina 38
# Raspando pagina 39
# Raspando pagina 40
# Raspando pagina 41
# Raspando pagina 42
# Raspando pagina 43
# Raspando pagina 44
# Raspando pagina 45
# Raspando pagina 46
# Raspando pagina 47
# Raspando pagina 48
# Raspando pagina 49
# Raspando pagina 50
# Raspando pagina 51
# Raspando pagina 52
# Raspando pagina 53
# Raspando pagina 54
# Raspando pagina 55
# Raspando pagina 56
# Raspando pagina 57
# Raspando pagina 58
# Raspando pagina 59
# Raspando pagina 60
# Raspando pagina 61
# Raspando pagina 62
# Raspando pagina 63
# Raspando pagina 64
# Raspando pagina 65
# Raspando pagina 66
# Raspando pagina 67
# Raspando pagina 68
# Raspando pagina 69
# Raspando pagina 70
# Raspando pagina 71
# Raspando pagina 72
# Raspando pagina 73
# Raspando pagina 74
# Raspando pagina 75
# Raspando pagina 76
# Raspando pagina 77
# Raspando pagina 78
# Raspando pagina 79
# Raspando pagina 80
# Raspando pagina 81
# Raspando pagina 82
# Raspando pagina 83

# %%
#Titulo descricao
driver = webdriver.Firefox(executable_path='C:/Windows/System32/drivers/DriverData/geckodriver.exe')
dados_titledesc=[]      
   

for i in range(1,84):
    PAGE = f'https://www.wine.com.br/vinhos/cVINHOS-p{i}.html'
    print(f'Raspando pagina {i}')

    driver.get(PAGE)  
    resultado = driver.find_elements_by_xpath("//*[@class='ProductDisplay-descriptionTitle']")
    for result in resultado:
        descTitle = result.text
        dados_titledesc.append({'Titulo_da_Descricao':descTitle})

quit_driver(driver)
df = pd.DataFrame(dados_titledesc, columns= ['Titulo_da_Descricao'])
df = df.apply(lambda x : removerAcentosECaracteresEspeciais(x['Titulo_da_Descricao']), axis=1)
df.to_csv('csv/titleDesc.csv')
# Out:
# Raspando pagina 1
# Raspando pagina 2
# Raspando pagina 3
# Raspando pagina 4
# Raspando pagina 5
# Raspando pagina 6
# Raspando pagina 7
# Raspando pagina 8
# Raspando pagina 9
# Raspando pagina 10
# Raspando pagina 11
# Raspando pagina 12
# Raspando pagina 13
# Raspando pagina 14
# Raspando pagina 15
# Raspando pagina 16
# Raspando pagina 17
# Raspando pagina 18
# Raspando pagina 19
# Raspando pagina 20
# Raspando pagina 21
# Raspando pagina 22
# Raspando pagina 23
# Raspando pagina 24
# Raspando pagina 25
# Raspando pagina 26
# Raspando pagina 27
# Raspando pagina 28
# Raspando pagina 29
# Raspando pagina 30
# Raspando pagina 31
# Raspando pagina 32
# Raspando pagina 33
# Raspando pagina 34
# Raspando pagina 35
# Raspando pagina 36
# Raspando pagina 37
# Raspando pagina 38
# Raspando pagina 39
# Raspando pagina 40
# Raspando pagina 41
# Raspando pagina 42
# Raspando pagina 43
# Raspando pagina 44
# Raspando pagina 45
# Raspando pagina 46
# Raspando pagina 47
# Raspando pagina 48
# Raspando pagina 49
# Raspando pagina 50
# Raspando pagina 51
# Raspando pagina 52
# Raspando pagina 53
# Raspando pagina 54
# Raspando pagina 55
# Raspando pagina 56
# Raspando pagina 57
# Raspando pagina 58
# Raspando pagina 59
# Raspando pagina 60
# Raspando pagina 61
# Raspando pagina 62
# Raspando pagina 63
# Raspando pagina 64
# Raspando pagina 65
# Raspando pagina 66
# Raspando pagina 67
# Raspando pagina 68
# Raspando pagina 69
# Raspando pagina 70
# Raspando pagina 71
# Raspando pagina 72
# Raspando pagina 73
# Raspando pagina 74
# Raspando pagina 75
# Raspando pagina 76
# Raspando pagina 77
# Raspando pagina 78
# Raspando pagina 79
# Raspando pagina 80
# Raspando pagina 81
# Raspando pagina 82
# Raspando pagina 83

# %%
#descricao
driver = webdriver.Firefox(executable_path='C:/Windows/System32/drivers/DriverData/geckodriver.exe')
dados_desc=[]      
   

for i in range(1,84):
    PAGE = f'https://www.wine.com.br/vinhos/cVINHOS-p{i}.html'
    print(f'Raspando pagina {i}')

    driver.get(PAGE)  
    resultado = driver.find_elements_by_xpath("//*[@class='ProductDisplay-descriptionText']")
    for result in resultado:
        desc = result.text
        dados_desc.append({'Descricao':desc})

quit_driver(driver)
df = pd.DataFrame(dados_desc, columns=['Descricao'])
df = df.apply(lambda x : removerAcentosECaracteresEspeciais(x['Descricao']), axis=1)
df.to_csv('csv/descricao.csv')
# Out:
# Raspando pagina 1
# Raspando pagina 2
# Raspando pagina 3
# Raspando pagina 4
# Raspando pagina 5
# Raspando pagina 6
# Raspando pagina 7
# Raspando pagina 8
# Raspando pagina 9
# Raspando pagina 10
# Raspando pagina 11
# Raspando pagina 12
# Raspando pagina 13
# Raspando pagina 14
# Raspando pagina 15
# Raspando pagina 16
# Raspando pagina 17
# Raspando pagina 18
# Raspando pagina 19
# Raspando pagina 20
# Raspando pagina 21
# Raspando pagina 22
# Raspando pagina 23
# Raspando pagina 24
# Raspando pagina 25
# Raspando pagina 26
# Raspando pagina 27
# Raspando pagina 28
# Raspando pagina 29
# Raspando pagina 30
# Raspando pagina 31
# Raspando pagina 32
# Raspando pagina 33
# Raspando pagina 34
# Raspando pagina 35
# Raspando pagina 36
# Raspando pagina 37
# Raspando pagina 38
# Raspando pagina 39
# Raspando pagina 40
# Raspando pagina 41
# Raspando pagina 42
# Raspando pagina 43
# Raspando pagina 44
# Raspando pagina 45
# Raspando pagina 46
# Raspando pagina 47
# Raspando pagina 48
# Raspando pagina 49
# Raspando pagina 50
# Raspando pagina 51
# Raspando pagina 52
# Raspando pagina 53
# Raspando pagina 54
# Raspando pagina 55
# Raspando pagina 56
# Raspando pagina 57
# Raspando pagina 58
# Raspando pagina 59
# Raspando pagina 60
# Raspando pagina 61
# Raspando pagina 62
# Raspando pagina 63
# Raspando pagina 64
# Raspando pagina 65
# Raspando pagina 66
# Raspando pagina 67
# Raspando pagina 68
# Raspando pagina 69
# Raspando pagina 70
# Raspando pagina 71
# Raspando pagina 72
# Raspando pagina 73
# Raspando pagina 74
# Raspando pagina 75
# Raspando pagina 76
# Raspando pagina 77
# Raspando pagina 78
# Raspando pagina 79
# Raspando pagina 80
# Raspando pagina 81
# Raspando pagina 82
# Raspando pagina 83

# %%
#Rating

driver = webdriver.Firefox(executable_path='C:/Windows/System32/drivers/DriverData/geckodriver.exe')
dados_rating=[]      
   

for i in range(1,84):
    PAGE = f'https://www.wine.com.br/vinhos/cVINHOS-p{i}.html'
    print(f'Raspando pagina {i}')

    driver.get(PAGE)  
    resultado = driver.find_elements_by_xpath("//*[@class='evaluation']")
    for result in resultado:
        rating = result.text
        dados_rating.append({'Rating':rating})

quit_driver(driver)
df = pd.DataFrame(dados_rating, columns=['Rating'])
df.to_csv('csv/rating.csv')
# Out:
# Raspando pagina 1
# Raspando pagina 2
# Raspando pagina 3
# Raspando pagina 4
# Raspando pagina 5
# Raspando pagina 6
# Raspando pagina 7
# Raspando pagina 8
# Raspando pagina 9
# Raspando pagina 10
# Raspando pagina 11
# Raspando pagina 12
# Raspando pagina 13
# Raspando pagina 14
# Raspando pagina 15
# Raspando pagina 16
# Raspando pagina 17
# Raspando pagina 18
# Raspando pagina 19
# Raspando pagina 20
# Raspando pagina 21
# Raspando pagina 22
# Raspando pagina 23
# Raspando pagina 24
# Raspando pagina 25
# Raspando pagina 26
# Raspando pagina 27
# Raspando pagina 28
# Raspando pagina 29
# Raspando pagina 30
# Raspando pagina 31
# Raspando pagina 32
# Raspando pagina 33
# Raspando pagina 34
# Raspando pagina 35
# Raspando pagina 36
# Raspando pagina 37
# Raspando pagina 38
# Raspando pagina 39
# Raspando pagina 40
# Raspando pagina 41
# Raspando pagina 42
# Raspando pagina 43
# Raspando pagina 44
# Raspando pagina 45
# Raspando pagina 46
# Raspando pagina 47
# Raspando pagina 48
# Raspando pagina 49
# Raspando pagina 50
# Raspando pagina 51
# Raspando pagina 52
# Raspando pagina 53
# Raspando pagina 54
# Raspando pagina 55
# Raspando pagina 56
# Raspando pagina 57
# Raspando pagina 58
# Raspando pagina 59
# Raspando pagina 60
# Raspando pagina 61
# Raspando pagina 62
# Raspando pagina 63
# Raspando pagina 64
# Raspando pagina 65
# Raspando pagina 66
# Raspando pagina 67
# Raspando pagina 68
# Raspando pagina 69
# Raspando pagina 70
# Raspando pagina 71
# Raspando pagina 72
# Raspando pagina 73
# Raspando pagina 74
# Raspando pagina 75
# Raspando pagina 76
# Raspando pagina 77
# Raspando pagina 78
# Raspando pagina 79
# Raspando pagina 80
# Raspando pagina 81
# Raspando pagina 82
# Raspando pagina 83

# %%
# Unificando os csv's
wine_dataset = merge_csv_folder(prefix = 'wine_dataset', path='C:/AIM_Program/Semana1_CapturaDeDados/csv/', memory='yes')
wine_dataset.drop(['0','Unnamed: 0'], axis=1, inplace = True)
wine_dataset.head(50)
# Out:
#     Awards          FRANCA            Cremoso boa acidez medio corpo elegante  \
# 0      NaN   NOVA ZELANDIA                 Taninos robustos final persistente
# 1      NaN          LIBANO  Corpo de leve para medio taninos macios boa ac...
# 2      NaN       ARGENTINA                            Boa acidez jovem fresco
# 3      NaN  ESTADOS UNIDOS               Boa acidez refrescante e equilibrado
# 4      NaN         ESPANHA             Leve frutado boa acidez taninos macios
# 5      NaN         ESPANHA  Frutado medio corpo acidez agradavel taninos m...
# 6      NaN         ESPANHA              Frutado bela acidez e final agradavel
# 7      NaN  ESTADOS UNIDOS  Frutado corpo de leve para medio taninos prese...
# 8      NaN         ESPANHA            Taninos aveludados frutado e boa acidez
# 9      NaN  ESTADOS UNIDOS  Frutado bom corpo taninos macios acidez agradavel
# 10     NaN        PORTUGAL  Aveludado notas frutadas com toque da madeira ...
# 11     NaN       ARGENTINA                             Frutado taninos suaves
# 12     NaN          FRANCA               Equilibrado taninos suaves bom final
# 13     NaN        PORTUGAL                         Fresco aveludado e frutado
# 14     NaN        PORTUGAL        Potente estruturado e com taninos marcantes
# 15     NaN          ITALIA                 Corpo medio estruturado e marcante
# 16     NaN          FRANCA           Leve refrescante boa cremosidade frutado
# 17     NaN          ITALIA                          Suculento frutado e jovem
# 18     NaN          ITALIA                     Encorpado saboroso e bom final
# 19     NaN          FRANCA             Harmonico boa acidez final persistente
# 20     NaN          FRANCA               Leve fresco frutado floral bom final
# 21     NaN          ITALIA                 Leve fresco jovem e com boa acidez
# 22     NaN          ITALIA            Bom corpo saboroso e com final elegante
# 23     NaN   AFRICA DO SUL  Tem bom corpo taninos presentes boa acidez e u...
# 24     NaN   AFRICA DO SUL                         Harmonico agradavel e leve
# 25     NaN          FRANCA                    Acidez equilibrada fresco jovem
# 26     NaN          FRANCA                               Harmonico boa acidez
# 27     NaN          ITALIA  Medio corpo taninos presentes boa acidez amade...
# 28     NaN          FRANCA  Medio corpo boa acidez frutado taninos macios ...
# 29     NaN        PORTUGAL                    Leve agradavel taninos redondos
# 30     NaN          FRANCA  Frutado amadeirado corpo de medio para encorpa...
# 31     NaN           CHILE                      Frutado leve acidez agradavel
# 32     NaN          ITALIA  Corpo de leve para medio acidez agradavel tani...
# 33     NaN       ARGENTINA        Elegante cremoso boa acidez final agradavel
# 34     NaN           CHILE  Estruturado cremoso frutado boa acidez final p...
# 35     NaN           CHILE  Estruturado cremoso frutado boa acidez final p...
# 36     4.0           CHILE             Elegante encorpado cremoso final longo
# 37     3.0           CHILE             Elegante encorpado cremoso final longo
# 38     3.0          FRANCA  Estruturado cremoso frutado boa acidez final p...
# 39     4.0          FRANCA                        Medio corpo boa acidez doce
# 40     NaN          FRANCA     Frutado bom corpo cremoso boa acidez adocicado
# 41     NaN          FRANCA  Medio corpo taninos macios acidez agradavel tosta
# 42     NaN          FRANCA  Estruturado cremoso frutado boa acidez final p...
# 43     4.0          FRANCA  Estruturado frutado fresco taninos macios fina...
# 44     1.0       ARGENTINA  Corpo de leve para medio acidez agradavel tani...
# 45     NaN          FRANCA  Medio corpo fresco taninos macios frutado fina...
# 46     NaN         ESPANHA  Corpo de leve para medio fresco frutado boa cr...
# 47     NaN          FRANCA  Elegante complexo bom corpo cremoso boa acidez...
# 48     NaN           CHILE            Leve frutado boa acidez final agradavel
# 49     NaN          BRASIL                           Leve docura sutil fresco
#
#        Mls                           Champagne Montaudon Brut    Sku  \
# 0    750.0                    Chateau Oumsiyat Red Syrah 2015   3170
# 1    750.0                 Latitud 33 Cabernet Sauvignon 2018  22892
# 2    750.0  Dark Horse The Original California Sauvignon B...  22925
# 3    750.0                       Sovento Sauvignon Blanc 2018  22840
# 4    750.0          Finca Ventura DOP Jumilla Monastrell 2018  22855
# 5    750.0      Senorio de Ayud Cabernet Sauvignon Syrah 2018  22820
# 6    750.0       Dark Horse The Original California Rose 2018  22834
# 7    750.0                Senorio De Ayud Garnacha Syrah 2018  22842
# 8    750.0    Dark Horse The Original Cabernet Sauvignon 2017  22835
# 9    750.0                             Latitud 33 Malbec 2018  22841
# 10   750.0                           Ropiteau Pinot Noir 2017  22749
# 11   750.0                    Papa Acorda Colheita Tinto 2018  22807
# 12   750.0             Castelo dos Mouros Colheita Tinto 2017  22988
# 13   750.0                           San Ceteo Primitivo 2017  22987
# 14   750.0              La Combe D Or Cabernet Sauvignon 2018  22997
# 15   750.0                            San Ceteo Turandot 2018  22975
# 16   750.0  Espumante Fantinel Prosecco One  Only DOC Brut...  22996
# 17   750.0                            L Empreinte Merlot 2018  22961
# 18   750.0               L  Empreinte Cabernet Sauvignon 2018  22974
# 19   750.0                          San Ceteo Sangiovese 2018  22973
# 20   750.0  Fantinel Borgo Tesis Pinot Grigio Doc Friuli 2018  22998
# 21   750.0                              Bonne Esperance White  22959
# 22   750.0                    Bouquet Cabernet Sauvignon 2018  22969
# 23   750.0  Fantinel Borgo Tesis Doc Grave Cabernet Sauvig...  22970
# 24   750.0                 La Combe D Or Sauvignon Blanc 2018  22958
# 25   750.0                   Papa Acorda Colheita Branco 2018  22978
# 26   750.0                                Bouquet Merlot 2018  22989
# 27   750.0         Miguel Torres Reserva Ancestral Blend 2015  22971
# 28   750.0          Carpineto Dogajolo IGT Toscano Rosso 2017  22622
# 29   750.0                             La Chamiza Malbec 2018  22657
# 30   750.0           Calyptra Vivendo Reserve Assemblage 2016  22632
# 31   750.0            Canepa Reserva Famiglia Chardonnay 2018  22659
# 32   750.0                                 Wanaco Merlot 2018  22626
# 33   750.0              Champagne Veuve Clicquot Brut 1500 ml  22726
# 34     1.5  Champagne Veuve Clicquot Rose Brut com Caixa Call  22706
# 35   750.0  Champagne Veuve Clicquot Rose Brut com Couture...  22710
# 36   750.0  Champagne Moet  Chandon Imperial Rose Brut Mag...  22709
# 37  1500.0  Champagne Moet  Chandon Imperial Rose Brut Mag...  22703
# 38  1500.0        Champagne Veuve Clicquot Rose Brut com Cake  22700
# 39   750.0  Terrazas de los Andes Single Vineyard Petit Ma...  22708
# 40   375.0  Champagne Moet  Chandon Ice Imperial DemiSec c...  22712
# 41   750.0         Protos DO Ribera del Duero Tinto Fino 2017  22696
# 42   750.0                    Magnum Veuve Clicquot Brut Rose  22724
# 43  1500.0  Canepa Magnificum DO Valle del Maipo Cabernet ...  22711
# 44   750.0             Canepa Reserva Famiglia Carmenere 2018  22598
# 45   750.0      Frei Brothers Reserve Cabernet Sauvignon 2016  22429
# 46   750.0            Espumante Chevalier Blanc de Noirs Brut  22571
# 47   750.0         Champagne Veuve Clicquot Vintage Brut 2008  22546
# 48   750.0             Pueblo del Sol Reserva Chardonnay 2018  22497
# 49   750.0             Frisante Salton Frizz Prosecco Demisec  22360
#
#     Gustativo
# 0   Gustativo
# 1   Gustativo
# 2   Gustativo
# 3   Gustativo
# 4   Gustativo
# 5   Gustativo
# 6   Gustativo
# 7   Gustativo
# 8   Gustativo
# 9   Gustativo
# 10  Gustativo
# 11  Gustativo
# 12  Gustativo
# 13  Gustativo
# 14  Gustativo
# 15  Gustativo
# 16  Gustativo
# 17  Gustativo
# 18  Gustativo
# 19  Gustativo
# 20  Gustativo
# 21  Gustativo
# 22  Gustativo
# 23  Gustativo
# 24  Gustativo
# 25  Gustativo
# 26  Gustativo
# 27  Gustativo
# 28  Gustativo
# 29  Gustativo
# 30  Gustativo
# 31  Gustativo
# 32  Gustativo
# 33  Gustativo
# 34  Gustativo
# 35  Gustativo
# 36  Gustativo
# 37  Gustativo
# 38  Gustativo
# 39  Gustativo
# 40  Gustativo
# 41  Gustativo
# 42  Gustativo
# 43  Gustativo
# 44  Gustativo
# 45  Gustativo
# 46  Gustativo
# 47  Gustativo
# 48  Gustativo
# 49  Gustativo
